# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {"scores.Hygiene": {'$eq': 20}}
hygiene_results = establishments.find(hygiene_query)

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(hygiene_query))

# Display the first document in the results using pprint
pprint(establishments.find_one(hygiene_query))
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664ae6ad17eb7453a0b81a69'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(hygiene_results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene_df))

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  664ae6ad17eb7453a0b81a69   110681                  0
# 1  664ae6ad17eb7453a0b81dd4   612039                  0
# 2  664ae6ad17eb7453a0b82105   730933                  0
# 3  664ae6ad17eb7453a0b822cc   172735                  0
# 4  664ae6ad17eb7453a0b822e2   172953                  0
# 5  664ae6ad17eb7453a0b82c7c   512854                  0
# 6  664ae6ad17eb7453a0b82ea6  1537089                  0
# 7  664ae6ad17eb7453a0b843ca   155648                  0
# 8  664ae6ad17eb7453a0b84813  1012883                  0
# 9  664ae6ad17eb7453a0b8501f   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
rating_query = {"RatingValue": {"$gte": 4}}
rating_results = establishments.find(rating_query)

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(rating_query))

# Display the first document in the results using pprint
pprint(establishments.find_one(rating_query))
# Out:
# 31257
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664ae6ac17eb7453a0b7ff26'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
rating_df = pd.DataFrame(rating_results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(rating_df))

# Display the first 10 rows of the DataFrame
rating_df.head(10)
# Out:
# Rows in DataFrame:  31257
#                         _id   FHRSID  ChangesByServerID  \
# 0  664ae6ac17eb7453a0b7ff26  1043695                  0
# 1  664ae6ac17eb7453a0b7ff27   647177                  0
# 2  664ae6ac17eb7453a0b7ff28   289353                  0
# 3  664ae6ac17eb7453a0b7ff29   289352                  0
# 4  664ae6ac17eb7453a0b7ff2c   289560                  0
# 5  664ae6ac17eb7453a0b7ff2d   894592                  0
# 6  664ae6ac17eb7453a0b7ff2e   344689                  0
# 7  664ae6ac17eb7453a0b7ff2f  1043701                  0
# 8  664ae6ac17eb7453a0b7ff30   805703                  0
# 9  664ae6ac17eb7453a0b7ff31   805702                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# 2             PI/000002468  St Marys COE (aided) Primary School
# 3             PI/000002460                             The Ship
# 4             PI/000039927                              Mariner
# 5             PI/000074396                               Docker
# 6             PI/000002095             Folkestone Trawlers Shop
# 7             PI/000076360                      Pick Up Pintxos
# 8             PI/000073221            That Burger - Harbour Arm
# 9             PI/000073219             Dr Legumes - Harbour Arm
#
#                 BusinessType  BusinessTypeID  \
# 0    Restaurant/Cafe/Canteen               1
# 1          Pub/bar/nightclub            7843
# 2  School/college/university            7845
# 3          Pub/bar/nightclub            7843
# 4          Pub/bar/nightclub            7843
# 5          Retailers - other            4613
# 6          Retailers - other            4613
# 7     Takeaway/sandwich shop            7844
# 8     Takeaway/sandwich shop            7844
# 9    Restaurant/Cafe/Canteen               1
#
#                                 AddressLine1           AddressLine2  \
# 0                        East Cliff Pavilion          Wear Bay Road
# 1                              Wear Bay Road             Folkestone
# 2  St Marys Church Of England Primary School            Warren Road
# 3                               23 The Stade             Folkestone
# 4                               16 The Stade             Folkestone
# 5                         Folkestone Harbour  Harbour Approach Road
# 6                                1 The Stade             Folkestone
# 7                         Folkestone Harbour  Harbour Approach Road
# 8                         Folkestone Harbour  Harbour Approach Road
# 9                         Folkestone Harbour  Harbour Approach Road
#
#   AddressLine3  ...               LocalAuthorityWebSite  \
# 0   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 1         Kent  ...  http://www.folkestone-hythe.gov.uk
# 2   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 3         Kent  ...  http://www.folkestone-hythe.gov.uk
# 4         Kent  ...  http://www.folkestone-hythe.gov.uk
# 5   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 6         Kent  ...  http://www.folkestone-hythe.gov.uk
# 7   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 8   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 9   Folkestone  ...  http://www.folkestone-hythe.gov.uk
#
#          LocalAuthorityEmailAddress  \
# 0  foodteam@folkestone-hythe.gov.uk
# 1  foodteam@folkestone-hythe.gov.uk
# 2  foodteam@folkestone-hythe.gov.uk
# 3  foodteam@folkestone-hythe.gov.uk
# 4  foodteam@folkestone-hythe.gov.uk
# 5  foodteam@folkestone-hythe.gov.uk
# 6  foodteam@folkestone-hythe.gov.uk
# 7  foodteam@folkestone-hythe.gov.uk
# 8  foodteam@folkestone-hythe.gov.uk
# 9  foodteam@folkestone-hythe.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 1.195625, 'latitude': 51.083812}
# 1     {'longitude': 1.196408, 'latitude': 51.086058}
# 2     {'longitude': 1.194762, 'latitude': 51.085797}
# 3      {'longitude': 1.188537, 'latitude': 51.08084}
# 4      {'longitude': 1.188537, 'latitude': 51.08084}
# 5  {'longitude': 1.18590330311705, 'latitude': 51...
# 6      {'longitude': 1.188537, 'latitude': 51.08084}
# 7  {'longitude': 1.18590330311705, 'latitude': 51...
# 8  {'longitude': 1.18590330311705, 'latitude': 51...
# 9  {'longitude': 1.18590330311705, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4591.765489            False
# 1  4591.821311            False
# 2  4591.871474            False
# 3  4591.912145            False
# 4  4591.912145            False
# 5  4591.914705            False
# 6  4591.912145            False
# 7  4591.914705            False
# 8  4591.914705            False
# 9  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

penang_query = {"BusinessName": "Penang Flavours"}
penang_results = establishments.find(penang_query)

for result in penang_results:
    latitude = result["geocode"]["latitude"]
    longitude = result["geocode"]["longitude"]

degree_search = 0.01

query3 = {"$and": [{"geocode.latitude": {"$gt": latitude-degree_search}}, 
                  {"geocode.latitude": {"$lt": latitude+degree_search}},
                  {"RatingValue": {"$eq": 5}},
                 ]
        }
sort3 = [("scores.Hygiene", -1)]
limit = 5

# Print the results
result3 = list(establishments.find(query3).sort(sort3).limit(limit))
pprint(result3)
# Out:
# [{'AddressLine1': 'Shop 1',
#   'AddressLine2': 'Gloucester Avenue',
#   'AddressLine3': 'East Tilbury',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Essex Chef',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4634.793541689465,
#   'FHRSID': 931030,
#   'LocalAuthorityBusinessID': '16/00155/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM18 8RB',
#   'RatingDate': '2021-02-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('664ae6ad17eb7453a0b84a05'),
#   'geocode': {'latitude': 51.4804524, 'longitude': 0.4194243},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/931030',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'Waterson Road',
#   'AddressLine2': 'Chadwell St Mary',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'BusinessName': 'Carolyne House',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4636.553595158633,
#   'FHRSID': 390686,
#   'LocalAuthorityBusinessID': '14150/2004/2/000',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM16 4LD',
#   'RatingDate': '2021-09-03T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('664ae6ad17eb7453a0b8501d'),
#   'geocode': {'latitude': 51.481765, 'longitude': 0.372352},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/390686',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Playbarn',
#   'AddressLine2': 'Walton Hall Farm',
#   'AddressLine3': 'Waltons Hall Road',
#   'AddressLine4': 'Linford',
#   'BusinessName': 'Tots World At Walton Hall Farm',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4635.587580763411,
#   'FHRSID': 1397533,
#   'LocalAuthorityBusinessID': '21/00164/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SS17 0RH',
#   'RatingDate': '2021-08-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('664ae6ad17eb7453a0b84d5c'),
#   'geocode': {'latitude': 51.4947574, 'longitude': 0.4121281},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1397533',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'East Tilbury Road',
#   'AddressLine2': 'Linford',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'BusinessName': 'George And Dragon',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4635.3571752660855,
#   'FHRSID': 1255390,
#   'LocalAuthorityBusinessID': '20/00044/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SS17 0QT',
#   'RatingDate': '2020-10-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('664ae6ad17eb7453a0b84c6b'),
#   'geocode': {'latitude': 51.4878845214844, 'longitude': 0.411476999521255},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1255390',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Preem Tandoori And Balti',
#   'AddressLine2': '1B Gloucester Avenue',
#   'AddressLine3': 'East Tilbury',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Preem',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4634.763193722327,
#   'FHRSID': 1077306,
#   'LocalAuthorityBusinessID': '18/00156/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM18 8RB',
#   'RatingDate': '2021-03-03T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('664ae6ad17eb7453a0b849dc'),
#   'geocode': {'latitude': 51.480409, 'longitude': 0.420215},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1077306',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}]

# %%
# Convert result to Pandas DataFrame
result3_df = pd.DataFrame(result3)
result3_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  664ae6ad17eb7453a0b84a05   931030                  0
# 1  664ae6ad17eb7453a0b8501d   390686                  0
# 2  664ae6ad17eb7453a0b84d5c  1397533                  0
# 3  664ae6ad17eb7453a0b84c6b  1255390                  0
# 4  664ae6ad17eb7453a0b849dc  1077306                  0
#
#   LocalAuthorityBusinessID                    BusinessName  \
# 0              16/00155/CP                      Essex Chef
# 1         14150/2004/2/000                  Carolyne House
# 2              21/00164/CP  Tots World At Walton Hall Farm
# 3              20/00044/CP               George And Dragon
# 4              18/00156/CP                           Preem
#
#               BusinessType  BusinessTypeID              AddressLine1  \
# 0   Takeaway/sandwich shop            7844                    Shop 1
# 1          Caring Premises               5             Waterson Road
# 2  Restaurant/Cafe/Canteen               1                  Playbarn
# 3        Pub/bar/nightclub            7843         East Tilbury Road
# 4   Takeaway/sandwich shop            7844  Preem Tandoori And Balti
#
#            AddressLine2       AddressLine3  ...  \
# 0     Gloucester Avenue       East Tilbury  ...
# 1      Chadwell St Mary              Essex  ...
# 2      Walton Hall Farm  Waltons Hall Road  ...
# 3               Linford              Essex  ...
# 4  1B Gloucester Avenue       East Tilbury  ...
#
#              LocalAuthorityWebSite  LocalAuthorityEmailAddress  \
# 0  http://www.thurrock.gov.uk/food  foodsafety@thurrock.gov.uk
# 1  http://www.thurrock.gov.uk/food  foodsafety@thurrock.gov.uk
# 2  http://www.thurrock.gov.uk/food  foodsafety@thurrock.gov.uk
# 3  http://www.thurrock.gov.uk/food  foodsafety@thurrock.gov.uk
# 4  http://www.thurrock.gov.uk/food  foodsafety@thurrock.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0   {'longitude': 0.4194243, 'latitude': 51.4804524}
# 1     {'longitude': 0.372352, 'latitude': 51.481765}
# 2   {'longitude': 0.4121281, 'latitude': 51.4947574}
# 3  {'longitude': 0.411476999521255, 'latitude': 5...
# 4     {'longitude': 0.420215, 'latitude': 51.480409}
#
#       Distance NewRatingPending  \
# 0  4634.793542            False
# 1  4636.553595            False
# 2  4635.587581            False
# 3  4635.357175            False
# 4  4634.763194            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {"$match": {"scores.Hygiene": {"$eq": 0}}}
group_query = {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}}
sort_values = {"$sort": {"count": -1}}
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Rows in result: ", len(results))

# Print the first 10 results
for i in range(10):
    print(results[i])
# Out:
# Rows in result:  55
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(results_df))

# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
